# %% [markdown]
# # TASK 2: DATA MANIPULATION WITH PANDAS
#
# This task involves using the Pandas library to manipulate data.
#
#
# Responsibility:
#
# Load a CSV file into a Pandas Dataframe. Perform operationals like filtering data based on condition, handling missing values, and calculating summary statistics.

# %%
import pandas as pd

# %%
data=pd.read_csv('01.Data Cleaning and Preprocessing.csv')

# %%
data
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data.head(5)
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
data.tail(5)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 319        347.286         310.970  1.523       513.956  ...        61.141
# 320        399.135         319.576  1.451       570.058  ...        67.667
# 321        373.633         314.591  1.457       549.306  ...        66.446
# 322        364.081         308.559  1.523       504.852  ...        61.054
# 323        356.289         310.482  1.474       497.375  ...        58.247
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Observation      324 non-null    object
#  1   Y-Kappa          324 non-null    float64
#  2   ChipRate         319 non-null    float64
#  3   BF-CMratio       307 non-null    float64
#  4   BlowFlow         308 non-null    float64
#  5   ChipLevel4       323 non-null    float64
#  6   T-upperExt-2     322 non-null    float64
#  7   T-lowerExt-2     322 non-null    float64
#  8   UCZAA            299 non-null    float64
#  9   WhiteFlow-4      323 non-null    float64
#  10  AAWhiteSt-4      173 non-null    float64
#  11  AA-Wood-4        323 non-null    float64
#  12  ChipMoisture-4   323 non-null    float64
#  13  SteamFlow-4      323 non-null    float64
#  14  Lower-HeatT-3    322 non-null    float64
#  15  Upper-HeatT-3    322 non-null    float64
# ...

# %% [markdown]
# #### Statistical summary

# %%
data.describe(include='all')
# Out:
#        Observation     Y-Kappa    ChipRate  BF-CMratio     BlowFlow  \
# count          324  324.000000  319.000000  307.000000   308.000000
# unique         301         NaN         NaN         NaN          NaN
# top       31-00:00         NaN         NaN         NaN          NaN
# freq             2         NaN         NaN         NaN          NaN
# mean           NaN   20.635370   14.347937   87.464456  1237.837614
# std            NaN    3.070036    1.499095    7.995012   100.593735
# min            NaN   12.170000    9.983000   68.645000     0.000000
# 25%            NaN   18.382500   13.358000   81.823000  1193.215250
# 50%            NaN   20.845000   14.308000   86.739000  1273.138500
# 75%            NaN   23.032500   15.517000   92.372000  1289.196000
# max            NaN   27.600000   16.958000  121.717000  1351.240000
#
#         ChipLevel4   T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   \
# ...

# %%
# check for any missing values
data.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             5
# BF-CMratio          17
# BlowFlow            16
# ChipLevel4           1
# T-upperExt-2         2
# T-lowerExt-2         2
# UCZAA               25
# WhiteFlow-4          1
# AAWhiteSt-4        151
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        2
# Upper-HeatT-3        2
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          2
# WeakWashF            1
# SteamHeatF-3         2
# T-Top-Chips-4        1
# SulphidityL-4      151
# dtype: int64

# %%
# Droping the first coulmn
data.drop('Observation',axis=1,inplace=True)

# %% [markdown]
# ### Handling missing values

# %%
null=data.isnull().sum()
columns_to_consider = null[null< 6].index.tolist()
data.dropna(subset=columns_to_consider,inplace=True)
data
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10    16.520     121.717  1177.607      169.805        358.282
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 4      22.90    15.618      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 319    23.75    12.667      93.450  1178.252      276.955        347.286
# 320    19.80    12.558      94.352  1184.119      297.071        399.135
# 321    23.01    12.550      90.842  1188.517      289.826        373.633
# 322    24.32    13.083      88.910  1192.879      318.006        364.081
# 323    25.75    13.417      85.451  1186.342      248.312        356.289
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
data.fillna(data.median(),inplace=True)

# %%
data
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 0      23.10    16.520     121.717  1177.607      169.805        358.282
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 3      23.60    16.478      81.011  1334.877      213.527        350.938
# 4      22.90    15.618      93.244  1334.168      243.131        351.640
# ..       ...       ...         ...       ...          ...            ...
# 319    23.75    12.667      93.450  1178.252      276.955        347.286
# 320    19.80    12.558      94.352  1184.119      297.071        399.135
# 321    23.01    12.550      90.842  1188.517      289.826        373.633
# 322    24.32    13.083      88.910  1192.879      318.006        364.081
# 323    25.75    13.417      85.451  1186.342      248.312        356.289
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# #### Filtering data

# %%
data[data['BlowFlow']< 1000.0]['UCZAA']
# Out:
# 182    1.416
# 279    1.553
# 280    1.555
# 281    1.556
# 283    1.604
# Name: UCZAA, dtype: float64

# %%
data[data['Lower-HeatT-3']>330]
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 8      22.50    14.233      97.249  1346.900      330.325        352.687
# 9      24.70    13.850      96.208  1334.892      362.511        352.372
# 12     26.62    15.467      84.447  1334.255      386.971        349.392
# 13     27.20    16.083      82.839  1332.331      366.855        350.094
# ..       ...       ...         ...       ...          ...            ...
# 310    24.70    13.850      96.208  1334.892      362.511        352.372
# 313    26.62    15.467      84.447  1334.255      386.971        349.392
# 319    23.75    12.667      93.450  1178.252      276.955        347.286
# 320    19.80    12.558      94.352  1184.119      297.071        399.135
# 321    23.01    12.550      90.842  1188.517      289.826        373.633
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
data[(data['BlowFlow']>1200) & (data['WhiteFlow-4 ']<600)]
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 8      22.50    14.233      97.249  1346.900      330.325        352.687
# 9      24.70    13.850      96.208  1334.892      362.511        352.372
# 10     22.60    13.875      95.720  1351.240      383.731        347.683
# ..       ...       ...         ...       ...          ...            ...
# 309    22.50    14.233      97.249  1346.900      330.325        352.687
# 310    24.70    13.850      96.208  1334.892      362.511        352.372
# 311    22.60    13.875      95.720  1351.240      383.731        347.683
# 312    24.40    14.117      85.998  1330.104      394.234        348.089
# 313    26.62    15.467      84.447  1334.255      386.971        349.392
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# ...

# %%
data[data['ChipRate']<10]
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 284     20.2     9.983     102.237  1027.485      369.632        342.576
#
#      T-lowerExt-2    UCZAA  WhiteFlow-4   AAWhiteSt-4   ...  SteamFlow-4   \
# 284          298.56  1.639       454.091         6.135  ...        54.259
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 284        328.976         304.282      130.177      1000.752      1361.314
#
#      WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 284        3.88          41.85         252.565           30.38
#
# [1 rows x 22 columns]

# %%
data[data['ChipMoisture-4 ']<45]
# Out:
#      Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   T-upperExt-2   \
# 1      27.60    16.810      79.022  1328.360      341.327        351.050
# 2      23.19    16.709      79.562  1329.407      239.161        350.022
# 12     26.62    15.467      84.447  1334.255      386.971        349.392
# 13     27.20    16.083      82.839  1332.331      366.855        350.094
# 14     24.05    16.675      77.025  1284.386      246.336        350.317
# 38     18.45    12.917      84.483  1175.728      391.599        343.614
# 39     24.30    13.917      87.835  1190.889      390.140        341.081
# 40     27.10    13.558      83.117  1175.417      289.256        339.168
# 41     24.70    14.142      80.809  1171.734      104.205        340.222
# 63     24.70    16.183      72.611  1231.362      332.497        350.938
# 64     25.40    16.958      74.405  1230.776      295.522        350.216
# 65     23.50    16.542      80.093  1246.777      198.217        350.521
# ...
